# %%
import bs4
from bs4 import BeautifulSoup
import requests
import re

# %%
r = requests.get('http://www.ipu.ac.in/listinstitute041018.php')

# %%
bs = BeautifulSoup(r.content,features='lxml')

# %%
pattern = re.compile(r'(www\.)?(?P<abbreviation>[-\w]+)\.[.\w]+')

# %%
def fix_extraws(s) :
    s = s.strip()
    return re.sub('\s+',' ',s)

# %%
colleges= []

# %%
tables = bs.findAll('table')

# %%
for table in tables :
    trows = table.findAll('tr')
    for row in trows :
        check = row.find('a',href=True)
        if not check : 
            continue
        row_data = row.findAll('td')
        serial_no = fix_extraws(row_data[0].get_text())
        college_name = fix_extraws(row_data[1].get_text())
        match = pattern.match(row_data[2].get_text())
#         print(row_data[2].get_text(),match)
        abbrev = match['abbreviation']
        print(serial_no,college_name,abbrev)
#     break
# Out:
# www.ayjnihh.nic.in <re.Match object; span=(0, 18), match='www.ayjnihh.nic.in'>
# 1 Ali Yavar Jung National Institute For The Hearing Handicapped, Noida ayjnihh
# www.aiactr.ac.in <re.Match object; span=(0, 16), match='www.aiactr.ac.in'>
# 2 Ambedkar Institute of Advanced Communication Technologies & Research, Geeta Colony, Delhi – 110092 aiactr
# www.bpibs.in <re.Match object; span=(0, 12), match='www.bpibs.in'>
# 3 Bhai Parmanand Institute of Business Studies, Opp. Madhuban, Shakarpur (Extn.), Delhi - 110092 bpibs
# www.esic.nic.in <re.Match object; span=(0, 15), match='www.esic.nic.in'>
# 4 ESI - PGIMSR, ESI Hospital, Basaidarpur, New Delhi esic
# www.cdac.in <re.Match object; span=(0, 11), match='www.cdac.in'>
# 5 C-DAC, NOIDA (formaly Electronics Research & Development Centre of India) Govt. of India, Anusandhan Bhawan, C - 56/1, Institutional Area, Sector - 62, NOIDA cdac
# www.cbpacs.com <re.Match object; span=(0, 14), match='www.cbpacs.com'>
# 6 Ch. Brahm Prakash Ayurved Charak Sansthan, Khera Dabar, Najafgarh, Delhi - 110073 cbpacs
# www.vmmc-sjh.nic.in <re.Match object; span=(0, 19), match='www.vmmc-sjh.nic.in'>
# 7 College of Nursing, VMMC & Safdarjang Hospital, New Delhi - 110026 vmmc-sjh
# www.rmlh.nic.in <re.Match object; span=(0, 15), match='www.rmlh.nic.in'>
# 8 College of Nursing, Dr. Ram Manohar Lohia Hospital, New Delhi - 110001 rmlh
# www.hihrm.delhigovt.nic.in <re.Match object; span=(0, 26), match='www.hihrm.delhigovt.nic.in'>
# 9 Delhi Institute of Heritage Research & Management, 18A, Satsang Vihar Marg, Special Institute Area, New Delhi - 67 hihrm
# www.shmch.delhogovt.nic.in <re.Match object; span=(0, 26), match='www.shmch.delhogovt.nic.in'>
# 10 Dr. B. R. Sur Homeopathic Medical College and Hospital and Research Centre, Nanakpura, Moti Bagh, New Delhi - 110021 shmch
# www.rmlh.nic.in <re.Match object; span=(0, 15), match='www.rmlh.nic.in'>
# 11 Dr. Ram Manohar Lohia Hospital, Post Graduate Institute of Medical Education & Research (PGIMER), New Delhi rmlh
# www.dite.delhigovt.nic.in <re.Match object; span=(0, 25), match='www.dite.delhigovt.nic.in'>
# 12 Delhi Institute of Tool Engineering, Okhla Industrial Area, Phase - II, Delhi - 20, (Head Office at Wazirpur Industrial Area, Delhi - 110052) dite
# www.esic.nic.in <re.Match object; span=(0, 15), match='www.esic.nic.in'>
# 13 ESIC Dental College, Rohini, New Delhi - 110085 esic
# www.gbpit.in <re.Match object; span=(0, 12), match='www.gbpit.in'>
# 14 G. B. Pant Institute of Technology, Okhla, Phase-III, New Delhi gbpit
# www.gbpec.edu.in <re.Match object; span=(0, 16), match='www.gbpec.edu.in'>
# 15 G.B. Pant Govt. Engineering College,Okhla, Phase-III, New Delhi gbpec
# www.gecdelhi.ac.in <re.Match object; span=(0, 18), match='www.gecdelhi.ac.in'>
# 16 Ch. Brahm Prakash Govt. Engineering College, Behind Rao Tula Ram Hospital, Jaffarpur, New Delhi - 110073 gecdelhi
# www.nilerd.ac.in <re.Match object; span=(0, 16), match='www.nilerd.ac.in'>
# 17 National Institute of Labour Economics Research & Development (Formerly IAMR), Narela, Delhi 110040 nilerd
# www.iitdwarka.ac.in <re.Match object; span=(0, 19), match='www.iitdwarka.ac.in'>
# 18 Integrated Institute of Technology, Sector 9, Dwarka, New Delhi - 110075 iitdwarka
# www.nicfs.nic.in <re.Match object; span=(0, 16), match='www.nicfs.nic.in'>
# 19 Lok Nayak Jayaprakash Narayan National Institute of Criminology and Forensic Science, Sector 3, Outer Ring Road, Rohini, Delhi nicfs
# www.tte.delhigovt.nic.in <re.Match object; span=(0, 24), match='www.tte.delhigovt.nic.in'>
# 20 Meera Bai Integrated Institute of Technology, Maharani Bagh, New Delhi tte
# www.yogamdniy.nic.in <re.Match object; span=(0, 20), match='www.yogamdniy.nic.in'>
# 21 Morarji Desai National Institute of Yoga, 68, Ashoka Road, New Delhi yogamdniy
# www.nipccd.nic.in <re.Match object; span=(0, 17), match='www.nipccd.nic.in'>
# 22 National Institute ofPublic Coorperation and Child Development, 5, Siri Institutional Area, Hauz Khas, New Delhi - 110016 nipccd
# www.scertdelhi.nic.in <re.Match object; span=(0, 21), match='www.scertdelhi.nic.in'>
# 24 State Council of Education Research & Training, Varun Marg, Defence Colony, New Delhi scertdelhi
# www.northdmc.com <re.Match object; span=(0, 16), match='www.northdmc.com'>
# 25 NDMC Medical college at Hindu Rao Hospital, Malika Ganj, Delhi northdmc
# www.ambp.in <re.Match object; span=(0, 11), match='www.ambp.in'>
# 26 Ambedkar Institute of Technology, Shakarpur, Opp. Madhuban, Patparganj Road, Delhi - 92 (Earlier as Ambedkar Integrated Institute of Engineering & Technology) , ambp
# www.abitdelhi.in <re.Match object; span=(0, 16), match='www.abitdelhi.in'>
# 27 Aryabhatt Institute of Technology, Near Shakti Nagar, Tele Exchange, G.T. Karnal Road, New Delhi abitdelhi
# www.bpibs.in <re.Match object; span=(0, 12), match='www.bpibs.in'>
# 28 Guru Nanak Dev Institute of Technology, Institutional Area, Sector-15, Rohini, Delhi – 110089, Ph.011-27567819, 27552645 bpibs
# www.tte.delhigovt.nic.in <re.Match object; span=(0, 24), match='www.tte.delhigovt.nic.in'>
# 29 Kasturba Gandhi Institute of Technology, Pitampura, Muni Maya Ram Marg, New Delhi -110088 tte
# www.hindurao.com <re.Match object; span=(0, 16), match='www.hindurao.com'>
# 30 College of Medical Lab Technology, Hindu Rao Hospital, Malkaganj, Delhi hindurao
# www.tte.delhigovt.nic.in <re.Match object; span=(0, 24), match='www.tte.delhigovt.nic.in'>
# 31 Pusa Institute of Technology Pusa, New Delhi - 110012 Ph.:011-25843065 tte
# www.bsamch.ac.in <re.Match object; span=(0, 16), match='www.bsamch.ac.in'>
# 32 Dr. BSA Hospital Medical College Sector 6, Rohini Delhi-110085 bsamch
# www.niepid.in <re.Match object; span=(0, 13), match='www.niepid.in'>
# 35 National Institute for the Empowerment of Persons with Intellectual Disabilities (Formerly NIMH), C44A, Sec. 40 Guatam Budh Nagar, Noida-U.P.-201301 niepid
# www.aimt.ac.in <re.Match object; span=(0, 14), match='www.aimt.ac.in'>
# 1 Army Institute of Management & Technology, Plot No. M-1, Block No. P-5, Greater Noida- 201306 aimt
# www.aie.ac.in <re.Match object; span=(0, 13), match='www.aie.ac.in'>
# 2 Army Institute of Education, Plot No. M-1, Block No. P-5, Greater Noida- 201306 aie
# www.awesindia.com <re.Match object; span=(0, 17), match='www.awesindia.com'>
# 3 Army College of Medical Sciences,Near Base Hospital, Delhi Cantt, New Delhi awesindia
# www.bcihmct.ac.in <re.Match object; span=(0, 17), match='www.bcihmct.ac.in'>
# 4 Banarsidas Chandiwala Institute of Hotel Management & Catering Technology, Chandiwala Estate, Maa Anandmai Marg, Kalkaji, New Delhi - 110019 bcihmct
# www.bciit.ac.in <re.Match object; span=(0, 15), match='www.bciit.ac.in'>
# 5 Banarsidas Chandiwala Institute of Information Technology, Chandiwala Estate, Maa Anandmai Marg, Kalkaji, New Delhi - 110019 bciit
# www.bcips.ac.in <re.Match object; span=(0, 15), match='www.bcips.ac.in'>
# 6 Banarsidas Chandiwala Institute of Physiotherapy, Chandiwala Estate, Kalkaji, New Delhi - 110019 bcips
# www.bcips.ac.in <re.Match object; span=(0, 15), match='www.bcips.ac.in'>
# 7 Banarsidas Chandiwala Institute of Professional Studies, Sector - 11, (Opp. Metro Station), Dwarka, New Delhi - 75 bcips
# www.bpindia.com <re.Match object; span=(0, 15), match='www.bpindia.com'>
# 8 Bhagwan Parshuram Institute of Technology,PSP-4, Sector - 17, Rohini, Delhi bpindia
# www.coedelhi.bharatividyapeeth.edu <re.Match object; span=(0, 34), match='www.coedelhi.bharatividyapeeth.edu'>
# 9 Bharati Vidyapeeths College of Engineering, A-4, Paschim Vihar, New Delhi - 63 coedelhi
# www.bvicam.ac.in <re.Match object; span=(0, 16), match='www.bvicam.ac.in'>
# 10 Bharti Vidyapeeth Institute of Computer Applications & Management, A-4., Paschim Vihar, New Delhi - 110063 bvicam
# www.cpj.edu.in <re.Match object; span=(0, 14), match='www.cpj.edu.in'>
# 11 Chanderprabhu Jain College of Higer Studies, Plot No.-OCF, Sector A-8, Narela, Delhi cpj
# www.commit.org.in <re.Match object; span=(0, 17), match='www.commit.org.in'>
# 12 COMM-IT, CARRER ACADEMY ,(Minority Educational Institution) FC-31,DDA's Institutional Area(Near Pushpawati Singhania Hospital) Press Enclave Road, Sheikh Sarai, Ph-II, New Delhi -17 commit
# www.dspsr.in <re.Match object; span=(0, 12), match='www.dspsr.in'>
# 13 Delhi School of Professional Studies and Research, 9, Institutional Area, Sector-25, Rohini, Phase-III, Delhi dspsr
# www.dias.ac.in <re.Match object; span=(0, 14), match='www.dias.ac.in'>
# 14 Delhi Institute of Advance Studies, Plot No.6, Sector-25, Rohini, Delhi - 110085 dias
# www.dirdcollege.com <re.Match object; span=(0, 19), match='www.dirdcollege.com'>
# 15 Delhi Institute of Rural Development, Holambi Khurd, Delhi - 110082 dirdcollege
# www.dirdcollege.com <re.Match object; span=(0, 19), match='www.dirdcollege.com'>
# 16 Delhi Institute of Rural Development, (Sister Branch of DIRD), G.T.Karnal RoadVillage Nangali Puna, Delhi-110036. dirdcollege
# www.dme.ac.in <re.Match object; span=(0, 13), match='www.dme.ac.in'>
# 17 Delhi Metropolitan Education (Sunshine Education & Development (Sunshine Education & Development Society) 28/1, Knowledge Park - III, Greater NOIDA, UP dme
# www.delhitechnicalcampus.ac.in <re.Match object; span=(0, 30), match='www.delhitechnicalcampus.ac.in'>
# 18 Delhi Technical Campus, 28/1, Knowledge Park - III, Greater NOIDA, UP delhitechnicalcampus
# www.dttcollege.org <re.Match object; span=(0, 18), match='www.dttcollege.org'>
# 19 DELHI TEACHERS TRAINING COLLEGE, 340, Deen Pur, Bijwasan Road, Nazafgarh, New Delhi. dttcollege
# www.fimt-ggsipu.org <re.Match object; span=(0, 19), match='www.fimt-ggsipu.org'>
# 20 FAIRFIELD INSTITUTE OF MANAGEMENT & TECHNOLOGY Plot No.1037/1, Kapashera, New Delhi - 110037 fimt-ggsipu
# www.giast.org <re.Match object; span=(0, 13), match='www.giast.org'>
# 21 GITARATTAN INSTITUTE OF ADVANCED STUDIES & TRAINING D-Block, Sector-7, Rohini, Delhi - 110085 giast
# www.gitarattan.edu.in <re.Match object; span=(0, 21), match='www.gitarattan.edu.in'>
# 22 GITARATTAN INTERNATIONAL BUSINESS SCHOOL Rohini Educational Society at PSP, Complex-II, Madhuban Chowk, Delhi gitarattan
# www.gncedelhi.org <re.Match object; span=(0, 17), match='www.gncedelhi.org'>
# 23 GURU NANAK COLLEGE OF EDUCATION, (Minority Educational Institution), Road No.75, Punjabi Bagh, New Delhi - 110026 gncedelhi
# www.gnim.ac.in <re.Match object; span=(0, 14), match='www.gnim.ac.in'>
# 24 GURU NANAK INSTITUTE OF MANAGEMENT, Road No.75, Punjabi Bagh(West), New Delhi - 110026 gnim
# www.grdce.com <re.Match object; span=(0, 13), match='www.grdce.com'>
# 25 GURU RAM DASS COLLEGE OF EDUCATION West Jyoti Nagar, Shahdara, Delhi grdce
# www.gtbit.org <re.Match object; span=(0, 13), match='www.gtbit.org'>
# 26 GURU TEGH BAHADUR INSTITUTE OF TECHNOLOGY (Minority Educational Institution)G-8, Area, Rajouri Garden, Opp. Swarg Ashram Mandir,Delhi - 110064 gtbit
# www.hmritm.ac.in <re.Match object; span=(0, 16), match='www.hmritm.ac.in'>
# 27 HMR INSTITUTE OF TECHNOLOGY & MANAGEMENT Hameed Pur, Delhi -110036 hmritm
# www.idealinstitute.edu.in <re.Match object; span=(0, 25), match='www.idealinstitute.edu.in'>
# 28 IDEAL INSTITUTE OF MANAGEMENT AND TECHNOLOGY 16-X, Karkardooma (Near Telephone Exchange), Vivek Vihar, Delhi -110092 idealinstitute
# www.isiconline.org <re.Match object; span=(0, 18), match='www.isiconline.org'>
# 29 ISIC INSTITUTE OF REHABILITATION SCIENCES Sector-C, Vasant Kunj, New Delhi - 110070 isiconline
# www.indianredcross.org <re.Match object; span=(0, 22), match='www.indianredcross.org'>
# 30 INDIAN RED CROSS SOCIETY 1, Red Cross Road, New Delhi indianredcross
# www.iitmjanakpuri.com <re.Match object; span=(0, 21), match='www.iitmjanakpuri.com'>
# 31 INSTITUTE OF INFORMATION TECHNOLOGY & MANAGEMENT D-29, Institutional Area, Janak Puri, New Delhi -110 058 iitmjanakpuri
# www.iitmjp.ac.in <re.Match object; span=(0, 16), match='www.iitmjp.ac.in'>
# 32 INSTITUTE OF INNOVATION IN TECHNOLOGY AND MANAGEMENT ,D-27 & 28, Institutional Area, Jankpuri, New Delhi iitmjp
# www.awadh.org.in <re.Match object; span=(0, 16), match='www.awadh.org.in'>
# 33 INSTITUTE OF VOCATIONAL STUDIES (Minority Educational Institution) FC-31, DDA's Institutional Area, Press Enclave Road, Sheikh Sarai, Ph-II, New Delhi - 110017 awadh
# www.jimsindia.org <re.Match object; span=(0, 17), match='www.jimsindia.org'>
# 34 JAGAN INSTITUTE OF MANAGEMENT STUDIES (ROHINI) 3, Institutional Area, Sector5, Rohini, (Near Rajiv Gandhi Cancer Research institute), Delhi - 85 jimsindia
# www.jimsd.org <re.Match object; span=(0, 13), match='www.jimsd.org'>
# 35 JAGANNATH INTERNATIONAL MANAGEMENT SCHOOL OCF, Pocket-9, Sector-B, Vasant Kunj, New Delhi -110070 jimsd
# www.jagannath.org <re.Match object; span=(0, 17), match='www.jagannath.org'>
# 36 Jagannath International Management School MOR Pkt-105 Kalkaji (Opp. Kalkaji Police Station), New Delhi-110 019 jagannath
# www.jimsgn.org <re.Match object; span=(0, 14), match='www.jimsgn.org'>
# 37 JIMS Engineering Management Technical Campus, 48/4, Knowledge Park - III, Greater NOIDA jimsgn
# www.kalkaeducationalsociety.com <re.Match object; span=(0, 31), match='www.kalkaeducationalsociety.com'>
# 38 KALKA INSTITUTE FOR RESEARCH AND ADVANCED STUDIES, Kalka Public School Campus, Alaknanda, New Delhi - 110019 kalkaeducationalsociety
# www.krcollege.in <re.Match object; span=(0, 16), match='www.krcollege.in'>
# 39 KASTURI RAM COLLEGE OF HIGHER EDUCATION Vill. Kureni(Khasra No.17/1/2/3 and 33/3) Narela, Delhi - 110040 krcollege
# www.lbsim.ac.in <re.Match object; span=(0, 15), match='www.lbsim.ac.in'>
# 40 LAL BAHADUR SHASTRI INSTITUTE OF MANAGEMENT, Plot No.11/7, Sector-11, Dwarka, New Delhi – 110075 lbsim
# www.lingayasgroup.org <re.Match object; span=(0, 21), match='www.lingayasgroup.org'>
# 41 LINGAYA'S LALITA DEVI INSTITUTE OF MANAGEMENT AND SCIENCES , 847-848, Mandi Road, Vill.Mandi, New Delhi - 110047 lingayasgroup
# www.batrahospitaldelhi.org <re.Match object; span=(0, 26), match='www.batrahospitaldelhi.org'>
# 42 LAKSHMI BAI BATRA COLLEGE OF NURSING Plot No.45,46, and 47, Tuglakabad, Institutional Area, Mehrauli Badarpur Road, New Delhi - 62 batrahospitaldelhi
# www.maims.ac.in <re.Match object; span=(0, 15), match='www.maims.ac.in'>
# 43 MAHARAJA AGRASEN INSTITUTE OF MANAGEMENT STUDIES Sector-22, Rohini, Delhi - 110085 maims
# www.mait.ac.in <re.Match object; span=(0, 14), match='www.mait.ac.in'>
# 44 MAHARAJA AGRASEN INSTITUTE OF TECHNOLOGY Sector-22, Rohini, Delhi - 110085 mait
# www.msi-ggsip.org <re.Match object; span=(0, 17), match='www.msi-ggsip.org'>
# 45 MAHARAJA SURAJMAL INSTITUTE C-4, Janak Puri, New Delhi-110058 msi-ggsip
# www.msit.in <re.Match object; span=(0, 11), match='www.msit.in'>
# 46 MAHARAJA SURAJMAL INSTITUTE OF TECHNOLOGY C-4, Janak Puri, New Delhi-110058 msit
# www.msitsnp.in <re.Match object; span=(0, 14), match='www.msitsnp.in'>
# 47 Mahavir Swami Institute of Technology, Sonepat, Haryana (Minority Institution) msitsnp
# www.meri.edu.in <re.Match object; span=(0, 15), match='www.meri.edu.in'>
# 48 MANAGEMENT EDUCATION & RESEARCH INSTITUTE 53-54, Institutional Area, Janak Puri, New Delhi - 110058 meri
# www.mbsarchitecture.org.in <re.Match object; span=(0, 26), match='www.mbsarchitecture.org.in'>
# 49 MBS School of Planning and Architecture, Sector-09, Dwarka, New Delhi- 110075 mbsarchitecture
# www.ndimdelhi.in <re.Match object; span=(0, 16), match='www.ndimdelhi.in'>
# 50 NEW DELHI INSTITUTE OF MANAGEMENT 60& 61, Tughlakabad Institutional Area, New Delhi – 110062 ndimdelhi
# www.adgitmdelhi.ac.in <re.Match object; span=(0, 21), match='www.adgitmdelhi.ac.in'>
# 51 Dr. Akhilesh Das Gupta Institute of Technology and Management,FC-26, SHASTRI PARK, New Delhi, Delhi 110053 adgitmdelhi
# www.pmcce.org <re.Match object; span=(0, 13), match='www.pmcce.org'>
# 52 PRADEEP MEMORIAL COMPREHENSIVE COLLEGE OF EDUCATION, Pratap Vihar, Kirari Extn., Nangloi, Delhi - 110041 pmcce
# www.pmccdelhi.com <re.Match object; span=(0, 17), match='www.pmccdelhi.com'>
# 53 Periyar Management and Computer College, 1 & 2 Institutional Area, New Delhi - 110025 pmccdelhi
# www.rgcirc.org <re.Match object; span=(0, 14), match='www.rgcirc.org'>
# 54 RAJIV GANDHI CANCER INSTITUTE AND RESEARCH CENTRE Sector-5, Rohini, New Delhi-110085 rgcirc
# www.rcitindia.org.in <re.Match object; span=(0, 20), match='www.rcitindia.org.in'>
# 55 R.C. INSTITUTE OF TECHNOLOGY Gopal Nagar, Najafgarh, New Delhi - 110043 rcitindia
# www.rdias.ac.in <re.Match object; span=(0, 15), match='www.rdias.ac.in'>
# 56 RUKMINI DEVI INSTITUTE OF ADVANCED STUDIES 2A&2B, Ph-I, Madhuban Chowk, Rohini, Delhi - 110085 rdias
# santharidasscollege.com <re.Match object; span=(0, 23), match='santharidasscollege.com'>
# 57 SANT HARI DASS COLLEGE OF HIGHER EDUCATION (Opp. Air Force Station), Bani Camp, Najafgarh, New Delhi – 43 santharidasscollege
# www.srifort.com <re.Match object; span=(0, 15), match='www.srifort.com'>
# 58 Sirifort Institute of Management Studies, Plot No. 8, Sector – 25, Rohini, New Delhi srifort
# www.sgtbimit.com <re.Match object; span=(0, 16), match='www.sgtbimit.com'>
# 59 Sri Guru Tegh Bahadur Institute of Management and Information Technology Gurudwara Nanak Piao, G.T.K. Road, Delhi - 110033 sgtbimit
# www.srite.in <re.Match object; span=(0, 12), match='www.srite.in'>
# 60 Sri Ram Institute of Teacher Education Village Bamnoli, Sector-28, Dwarka, New Delhi -110045 srite
# www.shrikrishnacollege.com <re.Match object; span=(0, 26), match='www.shrikrishnacollege.com'>
# 61 Shri Krishna College of Education, Plot / Khasra: 234, Johnamani, Daula, Baghpat, Uttar Pradesh shrikrishnacollege
# www.ashtavakra.in <re.Match object; span=(0, 17), match='www.ashtavakra.in'>
# 62 Ashtavakra Institute of Rehabilitation Sciences & Research, 5 PSP, Madhuban Chowk, Pitampura, Delhi ashtavakra
# www.stlawrence.in <re.Match object; span=(0, 17), match='www.stlawrence.in'>
# 63 ST. LAWRENCE COLLEGE OF HIGHER EDUCATION Geeta Colony, Facility center, Delhi-110030 stlawrence
# www.ststephenshospital.org <re.Match object; span=(0, 26), match='www.ststephenshospital.org'>
# 64 ST. STEPHEN'S COLLEGE OF NURSING. Tis Hazari, Delhi ststephenshospital
# www.tiaspg.tecnia.in <re.Match object; span=(0, 20), match='www.tiaspg.tecnia.in'>
# 65 TECNIA INSTITUTE OF ADVANCED STUDIES Madhuban Chowk, Rohini, Delhi - 110085 tiaspg
# www.tips.edu.in <re.Match object; span=(0, 15), match='www.tips.edu.in'>
# 66 TRINITY INSTITUTE OF PROFESSIONAL STUDIES Sector-9, Dwarka, (Adjacent to Metro Pillar No.1160) New Delhi - 110075 tips
# www.vakaarchitecture.com <re.Match object; span=(0, 24), match='www.vakaarchitecture.com'>
# 67 Vastu Kala Academy, 9/1, Aruna Asaf Ali Marg, New Delhi - 110067 vakaarchitecture
# www.vips.edu <re.Match object; span=(0, 12), match='www.vips.edu'>
# 69 VIVEKANANDA INSTITUTE OF PROFESSIONAL STUDIES AU Block (Outer Ring Road), Pitampura, New Delhi. vips
# www.kamalinstitute.com <re.Match object; span=(0, 22), match='www.kamalinstitute.com'>
# 70 Kamal Institute of Higher Education and Advance Technology K-1 (Block) Mohan Garden, New Delhi-59 kamalinstitute
# www.bmsasnp.com <re.Match object; span=(0, 15), match='www.bmsasnp.com'>
# 71 Bhagwan Mahaveer School of Architecture, Jagdishpur, Near O.P. Jindal University, Sonepat, Haryana,(Minority Institute) bmsasnp
# www.sgit.ac.in <re.Match object; span=(0, 14), match='www.sgit.ac.in'>
# 72 SGIT School of Management, NH-24, Opp. Jindal Pipes Ltd., Jindal Nagar, Gaziabad - 201302 sgit
# www.autism-india.org <re.Match object; span=(0, 20), match='www.autism-india.org'>
# 73 Action for Autism National Centre for Autism India The National Centre for Autism India, Pocket 7 & 8, Jasola Vihar, New Delhi 110025 autism-india
# www.bmiet.net <re.Match object; span=(0, 13), match='www.bmiet.net'>
# 74 BM Institute of Engineering & Technology, Behind Fazilpur Power Station Sonepath, Bahalgarh Road, Village Raipur, Sonepat, Haryana bmiet
# www.bmcemsnp.com <re.Match object; span=(0, 16), match='www.bmcemsnp.com'>
# 75 Bhagwan Mahaveer College of Engineering & Management, Jatheri Road, Barota Chowki, Jagdishpur, Sonepat bmcemsnp
# www.nationalheartinstitute.com <re.Match object; span=(0, 30), match='www.nationalheartinstitute.com'>
# 76 National Heart Institute, 49-50, Community Centre, East of Kailash, New Delhi 110065 nationalheartinstitute
# www.bvbdelhi.org <re.Match object; span=(0, 16), match='www.bvbdelhi.org'>
# 77 Leelawati Munshi College of Education, Bharatiya Vidya Bhavan 01, Kasturba Gandhi Marg, New Delhi 110001 bvbdelhi
# www.vivekanand.ac.in <re.Match object; span=(0, 20), match='www.vivekanand.ac.in'>
# 78 Vivekanand College of Professional Studies,NH-24, Delhi-Hapur Road, Jindal Nagar, Delhi-NCR, Ghaziabad, U.P. vivekanand
# www.accmanbusinessschool.in <re.Match object; span=(0, 27), match='www.accmanbusinessschool.in'>
# 79 ACCMAN Business School, 46-A/2, Knowledge Park-III, Greater Noida, U.P. accmanbusinessschool
# www.rkgit.edu.in <re.Match object; span=(0, 16), match='www.rkgit.edu.in'>
# 80 Raj Kumar Goel Engineering College, Pilkhuwa, Hapur, U.P. rkgit
# www.gniotgroup.edu.in <re.Match object; span=(0, 21), match='www.gniotgroup.edu.in'>
# 81 Greater Noida Institute of Technology, Plot No. 6C, Knowledge Park-II, Greater Noida, U.P. gniotgroup
# www.ditmcollege.com <re.Match object; span=(0, 19), match='www.ditmcollege.com'>
# 82 Delhi institute of Technology & Management, Gannaur, Sonepat ditmcollege
# www.united.ac.in <re.Match object; span=(0, 16), match='www.united.ac.in'>
# 83 United College of Education,Plot No. 50 Knowledge Park-III, Greater Noida, G B NAGAR U.P. united
# www.shrigopichand.org <re.Match object; span=(0, 21), match='www.shrigopichand.org'>
# 84 Sant Gopichand Education & Welfare Society, Ahera (Baghpat) U.P.-205609 shrigopichand
# www.kccilhe.com <re.Match object; span=(0, 15), match='www.kccilhe.com'>
# 85 KCC Institute of Legal & Higher Education, 2B-2C, Knowledge Park-III, Greater Noida, Gautam Budh Nagar kccilhe
